# %%
import pandas as pd

# %% [markdown]
# **Descriptive & Inferential Statistics**
# - Descriptive
# - - Descriptive statistics are used to describe the basic features of the data in a study. They provide simple summaries about the sample and the measures. Descriptive statistics can be quantitative, such as measures of central tendency (mean, median, mode), measures of variability (range, variance, standard deviation), or they can be visual, such as histograms, box plots, or scatter plots.
#
# Descriptive statistics are primarily concerned with providing an overview of the data and organizing it in a meaningful way, allowing researchers to understand the main characteristics and patterns present in the data set. They don't involve making inferences beyond the data at hand.
#
# For example, if you have a set of test scores for students in a class, descriptive statistics would tell you the average score, the spread of scores, the highest and lowest scores, etc.
# - Inferential
# - - Inferential statistics are used to make inferences or predictions about a population based on a sample of data taken from that population. It involves using sample data to make estimates, test hypotheses, and draw conclusions about the population from which the sample is drawn.
#
# Inferential statistics typically involve hypothesis testing, where researchers test whether observed differences or relationships in the sample are likely to reflect true differences or relationships in the population. This is done by assessing the probability that the observed results occurred by chance.
#
# Common techniques in inferential statistics include t-tests, analysis of variance (ANOVA), regression analysis, chi-square tests, and confidence intervals.
#
# For example, if you have a sample of test scores from a class, inferential statistics could help you determine whether there's a significant difference in the average scores between two groups, such as students who received tutoring versus those who did not.
#
# In summary, descriptive statistics aim to summarize and describe data, while inferential statistics aim to make inferences and predictions about populations based on sample data. Both are crucial in understanding and analyzing data in various fields, including science, social sciences, economics, and more.

# %%
import seaborn as sns
dataset = sns.load_dataset('penguins')

# %%
dataset
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.relplot(
    data=dataset,x='flipper_length_mm',y='bill_depth_mm',kind='line',hue='sex'
)

# %%
sns.displot(
    data=dataset,x='bill_length_mm',col='species',row='sex'
)

# %% [markdown]
# **Measure of center tendency**
# - mean (average)
# - median (center)
# - mode (most occure)
# -
#
# **Measure od dispersion**
# - variance
# - - In statistics, variance is a measure of how much a set of data points deviate from the mean (average) value of the data set.
# - Standard Deviation
# - - The root of variance is the the standard deviation. More accurate regarding to original data.
# -
# **Probability**
# - Probability is a fundamental concept in mathematics and statistics that quantifies the likelihood of an event occurring. It is used to analyze uncertain outcomes and make predictions based on data and assumptions. Here are the basics of probability:
#
# 1. **Sample Space**: The sample space (\( S \)) is the set of all possible outcomes of a random experiment. For example, when rolling a fair six-sided die, the sample space is \{1, 2, 3, 4, 5, 6\}.
#
# 2. **Event**: An event (\( E \)) is any subset of the sample space, representing a specific outcome or a combination of outcomes. Events can be simple (a single outcome) or compound (combinations of outcomes). For example, in rolling a die, the event of getting an even number is the set \{2, 4, 6\}.
#
# 3. **Probability of an Event**: The probability of an event (\( P(E) \)) is a numerical measure between 0 and 1 that quantifies the likelihood of the event occurring.
#     - \( 0 \leq P(E) \leq 1 \)
#     - \( P(\text{Impossible event}) = 0 \)
#     - \( P(\text{Certain event}) = 1 \)
#
# 4. **Calculating Probability**:
#     - For equally likely outcomes, the probability of an event is given by the ratio of the number of favorable outcomes to the total number of outcomes.
#     - \( P(E) = \frac{\text{Number of favorable outcomes}}{\text{Total number of outcomes}} \)
#     - For example, when rolling a fair die, \( P(\text{getting a 3}) = \frac{1}{6} \).
#
# 5. **Complement of an Event**: The complement of an event \( E \), denoted by \( E' \) or \( E^c \), is the event that consists of all outcomes in the sample space that are not in \( E \). The probability of the complement of an event is \( P(E') = 1 - P(E) \).
#
# 6. **Addition Rule**: For two events \( A \) and \( B \) (not necessarily mutually exclusive), the probability of the union of the two events is given by:
#     - \( P(A \cup B) = P(A) + P(B) - P(A \cap B) \)
#     - If \( A \) and \( B \) are mutually exclusive, \( P(A \cap B) = 0 \), and the formula simplifies to \( P(A \cup B) = P(A) + P(B) \).
#
# 7. **Multiplication Rule**:
#     - For independent events \( A \) and \( B \), the probability of both events occurring is the product of their individual probabilities: \( P(A \cap B) = P(A) \times P(B) \).
#     - For dependent events, the probability of the second event given that the first event has occurred is \( P(B|A) = \frac{P(A \cap B)}{P(A)} \).
#
# 8. **Conditional Probability**: Conditional probability is the probability of an event occurring given that another event has already occurred. It is denoted by \( P(B|A) \), the probability of event \( B \) occurring given that event \( A \) has occurred.
#
# These basic principles of probability provide a framework for understanding uncertainty and making informed decisions in various fields, including mathematics, statistics, economics, and science.

# %% [markdown]
# **Variance**
# - Measure of spread of data from it's mean.
# -
# **Co-variance**
# - Covariance measures the degree to which two random variables change together.
# -
# **Summary**
# - In summary, while variance measures the dispersion of a single variable, covariance measures the relationship between two variables.

# %% [markdown]
# **Center Limit Theorem**
# - The Central Limit Theorem states that if you take repeated samples from a population and calculate the mean of each sample, the distribution of those sample means will tend to follow a normal distribution as the sample size increases, even if the population distribution itself is not normal.
